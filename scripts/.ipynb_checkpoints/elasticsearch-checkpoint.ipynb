# %%
from ibm_watson import DiscoveryV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
# import logging
# from pprint import pprint
# from elasticsearch import Elasticsearch
# import pandas as pd

# %%
from elasticsearch import Elasticsearch

# Password for the 'elastic' user generated by Elasticsearch
ELASTIC_PASSWORD = "7ysm8X2-_DU1fiAwpkSh"

# Create the client instance
client = Elasticsearch(
    "https://localhost:9200",
    ca_certs=r"C:\Users\huzyfa\Desktop\elasticsearch-8.1.0\config\certs",
    basic_auth=("elastic", ELASTIC_PASSWORD)
)

# Successful response!
client.info()
# {'name': 'instance-0000000000', 'cluster_name': ...}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4472/1995452128.py in <module>
# ----> 1 from elasticsearch import Elasticsearch
#       2
#       3 # Password for the 'elastic' user generated by Elasticsearch
#       4 ELASTIC_PASSWORD = "7ysm8X2-_DU1fiAwpkSh"
#       5
#
# ModuleNotFoundError: No module named 'elasticsearch'

# %%
PUT hotels
# Out:
#   File "C:\Users\huzyfa\AppData\Local\Temp/ipykernel_6988/2066861464.py", line 1
#     PUT hotels
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
PUT hotels/_doc/1
POST hotels/_doc
{
    "settings":{
        "number_of_shards": 2,
        "number_of_replicas": 1,
        "refresh_interval": 60
    },
    "mappings": {
        "properties":{
            "address":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "categories":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "city":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "country":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "latitude":{
                "type": "double"                
            },
            "longitude":{
                "type": "double"
            },
            "name":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }            },
            "postalCode":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "province":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.date":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.dateAdded":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.doRecommend":{
                "type": "double"       
                # "enabled": false                       
            },
            "reviews.id":{
                "type": "double"                
            },
            "reviews.rating":{
                "type": "double"                
            },
            "reviews.text":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.title":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.userCity":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.username":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.userProvince":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            }
        }
    }
}
# Out:
#   File "C:\Users\huzyfa\AppData\Local\Temp/ipykernel_6988/2328127158.py", line 1
#     PUT hotels/_doc/1
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
ti = ((2, 5, 6))
tuple([i for i in ti])
# Out:
# (2, 5, 6)
