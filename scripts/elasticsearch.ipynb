# %%
# activate the virtualenv ```conda activate your_vertualenv``` 
# and in the same cmd run `jupyter lab` or `jupyter notebook` then
# !pip install elasticsearch

# %%
# change to the elasticsearch directoy and also activate the same virtualenv
# !./bin/elasticsearch.bat

# %%
import logging
from pprint import pprint
import pandas as pd
from datetime import datetime

# %%
from elasticsearch import Elasticsearch

# Password for the 'elastic' user generated by Elasticsearch
ELASTIC_PASSWORD = "7ysm8X2-_DU1fiAwpkSh"

# Create the client instance
es = Elasticsearch(
    "https://localhost:9200",
    ca_certs=r"C:\Users\huzyfa\Desktop\elasticsearch-8.1.0\config\certs\http_ca.crt",
    basic_auth=("elastic", ELASTIC_PASSWORD))

# Successful response!
es.info()
# {'name': 'instance-0000000000', 'cluster_name': ...}
# Out:
# ObjectApiResponse({'name': 'DESKTOP-2MEUV6N', 'cluster_name': 'elasticsearch', 'cluster_uuid': 'gfamsEa_RX-caFhzkL5nxw', 'version': {'number': '8.1.0', 'build_flavor': 'default', 'build_type': 'zip', 'build_hash': '3700f7679f7d95e36da0b43762189bab189bc53a', 'build_date': '2022-03-03T14:20:00.690422633Z', 'build_snapshot': False, 'lucene_version': '9.0.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %%
doc = {'author': 'Ahmad_Salama',
       'text': 'hotels data',
       'timestamp': datetime.now()}
doc = {
    "settings":{
        "number_of_shards": 1,
        "number_of_replicas": 0,
        "refresh_interval": 60
    },
    "mappings": {
        "properties":{
            "address":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "categories":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "city":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "country":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "latitude":{
                "type": "double"                
            },
            "longitude":{
                "type": "double"
            },
            "name":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }            },
            "postalCode":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "province":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.date":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.dateAdded":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.doRecommend":{
                "type": "double"       
                # "enabled": false                       
            },
            "reviews.id":{
                "type": "double"                
            },
            "reviews.rating":{
                "type": "double"                
            },
            "reviews.text":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.title":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.userCity":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.username":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.userProvince":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            }
        }
    }
}
resp = es.index(index="test-index", id=0, document=doc)

# %%
resp
# Out:
# ObjectApiResponse({'_index': 'test-index', '_id': '0', '_version': 9, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 11, '_primary_term': 1})

# %%
es.delete(index='test-index', id=0)
# Out:
# ObjectApiResponse({'_index': 'test-index', '_id': '0', '_version': 10, 'result': 'deleted', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 12, '_primary_term': 1})

# %%
df = pd.read_csv("../hotels.csv")#.set_index("name").groupby("name").all()
df
# Out:
#                       address  \
# 0      Riviera San Nicol 11/a
# 1      Riviera San Nicol 11/a
# 2      Riviera San Nicol 11/a
# 3      Riviera San Nicol 11/a
# 4      Riviera San Nicol 11/a
# ...                       ...
# 35907      1088 Powdermill Rd
# 35908      1088 Powdermill Rd
# 35909      1088 Powdermill Rd
# 35910        3747 29th St S E
# 35911        3747 29th St S E
#
#                                               categories          city  \
# 0                                                 Hotels      Mableton
# 1                                                 Hotels      Mableton
# 2                                                 Hotels      Mableton
# 3                                                 Hotels      Mableton
# 4                                                 Hotels      Mableton
# ...                                                  ...           ...
# 35907  Cabins,Resorts & Vacation Cottages,Wedding Cha...    Gatlinburg
# ...

# %%
es.put(df.loc[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6640/3435517831.py in <module>
# ----> 1 es.put(df.loc[0])
#
# AttributeError: 'Elasticsearch' object has no attribute 'put'

# %%
# !conda info

# %%
PUT hotels
# Out:
#   File "C:\Users\huzyfa\AppData\Local\Temp/ipykernel_6640/2066861464.py", line 1
#     PUT hotels
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     C:\Users\huzyfa\Anaconda3
# hm                    *  C:\Users\huzyfa\Anaconda3\envs\hm

# %%
9

# %%
# PUT hotels/_doc/1
POST hotels/_doc
{
    "settings":{
        "number_of_shards": 1,
        "number_of_replicas": 0,
        "refresh_interval": 60
    },
    "mappings": {
        "properties":{
            "address":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "categories":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "city":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "country":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "latitude":{
                "type": "double"                
            },
            "longitude":{
                "type": "double"
            },
            "name":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }            },
            "postalCode":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "province":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.date":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.dateAdded":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.doRecommend":{
                "type": "double"       
                # "enabled": false                       
            },
            "reviews.id":{
                "type": "double"                
            },
            "reviews.rating":{
                "type": "double"                
            },
            "reviews.text":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.title":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.userCity":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.username":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            },
            "reviews.userProvince":{
                "type": "text",
                "fields":{
                    "keyword":{
                        "type": "keyword"
                    }                
                }
            }
        }
    }
}
# Out:
#   File "C:\Users\huzyfa\AppData\Local\Temp/ipykernel_6640/1150167235.py", line 2
#     POST hotels/_doc
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
ti = ((2, 5, 6))
tuple([i for i in ti])
# Out:
# (2, 5, 6)
